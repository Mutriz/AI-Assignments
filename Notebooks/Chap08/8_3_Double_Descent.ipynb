# %% [markdown]
# <a href="https://colab.research.google.com/github/Mutriz/AI-Assignments/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-ghy05lvb
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-ghy05lvb
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.241530, train error 83.10,  test loss 2.221098, test error 81.82
# Epoch   100, train loss 1.926732, train error 72.57,  test loss 1.758903, test error 69.25
# Epoch   200, train loss 1.916929, train error 71.07,  test loss 1.762672, test error 69.40
# Epoch   300, train loss 1.910128, train error 70.25,  test loss 1.758027, test error 68.80
# Epoch   400, train loss 1.903165, train error 70.68,  test loss 1.750970, test error 68.72
# Epoch   500, train loss 1.900697, train error 70.70,  test loss 1.743684, test error 68.85
# Epoch   600, train loss 1.899579, train error 71.25,  test loss 1.729761, test error 69.47
# Epoch   700, train loss 1.900102, train error 71.22,  test loss 1.744895, test error 68.62
# Epoch   800, train loss 1.897245, train error 71.57,  test loss 1.738598, test error 69.40
# Epoch   900, train loss 1.897021, train error 71.28,  test loss 1.741186, test error 69.43
# Training model with   4 hidden variables
# Epoch     0, train loss 2.296842, train error 88.82,  test loss 2.300070, test error 89.45
# Epoch   100, train loss 1.794154, train error 67.30,  test loss 1.629448, test error 64.60
# Epoch   200, train loss 1.770244, train error 65.35,  test loss 1.610029, test error 62.35
# Epoch   300, train loss 1.758799, train error 64.90,  test loss 1.607913, test error 62.50
# Epoch   400, train loss 1.752849, train error 65.12,  test loss 1.602691, test error 62.40
# Epoch   500, train loss 1.756447, train error 65.10,  test loss 1.611978, test error 63.25
# Epoch   600, train loss 1.747152, train error 64.32,  test loss 1.608336, test error 61.70
# Epoch   700, train loss 1.752677, train error 64.72,  test loss 1.627476, test error 62.33
# Epoch   800, train loss 1.747744, train error 64.43,  test loss 1.621075, test error 62.20
# Epoch   900, train loss 1.744544, train error 64.00,  test loss 1.621624, test error 62.60
# Training model with   6 hidden variables
# Epoch     0, train loss 2.260797, train error 84.62,  test loss 2.250363, test error 84.30
# Epoch   100, train loss 1.659652, train error 60.10,  test loss 1.498867, test error 57.65
# Epoch   200, train loss 1.628266, train error 58.25,  test loss 1.484605, test error 57.40
# Epoch   300, train loss 1.619986, train error 57.72,  test loss 1.484234, test error 57.17
# Epoch   400, train loss 1.615853, train error 57.33,  test loss 1.491963, test error 56.83
# Epoch   500, train loss 1.612809, train error 57.83,  test loss 1.485148, test error 56.30
# Epoch   600, train loss 1.616026, train error 57.65,  test loss 1.499491, test error 56.80
# Epoch   700, train loss 1.609857, train error 57.03,  test loss 1.493413, test error 56.42
# Epoch   800, train loss 1.617729, train error 57.88,  test loss 1.507316, test error 57.83
# Epoch   900, train loss 1.612787, train error 58.35,  test loss 1.503848, test error 58.05
# Training model with   8 hidden variables
# Epoch     0, train loss 2.235920, train error 84.18,  test loss 2.216544, test error 83.57
# Epoch   100, train loss 1.627640, train error 57.35,  test loss 1.460642, test error 55.92
# Epoch   200, train loss 1.544529, train error 53.67,  test loss 1.421869, test error 53.40
# Epoch   300, train loss 1.533911, train error 53.40,  test loss 1.428203, test error 54.08
# Epoch   400, train loss 1.523509, train error 52.58,  test loss 1.426464, test error 53.70
# Epoch   500, train loss 1.513325, train error 52.50,  test loss 1.404938, test error 52.53
# Epoch   600, train loss 1.498583, train error 52.15,  test loss 1.404905, test error 52.80
# Epoch   700, train loss 1.485475, train error 51.83,  test loss 1.400172, test error 52.10
# Epoch   800, train loss 1.487856, train error 51.58,  test loss 1.405069, test error 52.22
# Epoch   900, train loss 1.489549, train error 52.00,  test loss 1.405135, test error 52.45
# Training model with  10 hidden variables
# Epoch     0, train loss 2.296354, train error 86.12,  test loss 2.300539, test error 85.80
# Epoch   100, train loss 1.577164, train error 55.72,  test loss 1.448412, test error 56.22
# Epoch   200, train loss 1.508818, train error 53.10,  test loss 1.438027, test error 56.17
# Epoch   300, train loss 1.475893, train error 51.95,  test loss 1.426050, test error 54.83
# Epoch   400, train loss 1.468271, train error 51.85,  test loss 1.428196, test error 54.10
# Epoch   500, train loss 1.460717, train error 50.92,  test loss 1.424460, test error 54.28
# Epoch   600, train loss 1.452443, train error 51.53,  test loss 1.437672, test error 54.38
# Epoch   700, train loss 1.449686, train error 51.08,  test loss 1.437146, test error 54.42
# Epoch   800, train loss 1.441312, train error 51.42,  test loss 1.445296, test error 54.58
# Epoch   900, train loss 1.433026, train error 50.88,  test loss 1.445539, test error 54.17
# Training model with  14 hidden variables
# Epoch     0, train loss 2.264822, train error 84.82,  test loss 2.264739, test error 82.97
# Epoch   100, train loss 1.401827, train error 48.25,  test loss 1.254044, test error 46.15
# Epoch   200, train loss 1.343028, train error 46.78,  test loss 1.268708, test error 46.45
# Epoch   300, train loss 1.322841, train error 45.00,  test loss 1.280534, test error 47.38
# Epoch   400, train loss 1.312502, train error 45.58,  test loss 1.309178, test error 48.05
# Epoch   500, train loss 1.298793, train error 44.25,  test loss 1.318139, test error 47.47
# Epoch   600, train loss 1.290603, train error 43.80,  test loss 1.332620, test error 47.70
# Epoch   700, train loss 1.279666, train error 43.95,  test loss 1.346310, test error 48.08
# Epoch   800, train loss 1.268918, train error 43.17,  test loss 1.368576, test error 47.70
# Epoch   900, train loss 1.259288, train error 43.03,  test loss 1.381072, test error 48.40
# Training model with  18 hidden variables
# Epoch     0, train loss 2.173073, train error 81.65,  test loss 2.137549, test error 79.38
# Epoch   100, train loss 1.352070, train error 46.00,  test loss 1.316235, test error 49.47
# Epoch   200, train loss 1.246818, train error 41.88,  test loss 1.336839, test error 50.03
# Epoch   300, train loss 1.213041, train error 40.90,  test loss 1.378626, test error 50.40
# Epoch   400, train loss 1.182108, train error 40.08,  test loss 1.420636, test error 50.72
# Epoch   500, train loss 1.173986, train error 39.67,  test loss 1.439948, test error 50.72
# Epoch   600, train loss 1.152439, train error 38.58,  test loss 1.446843, test error 50.67
# Epoch   700, train loss 1.142151, train error 38.58,  test loss 1.464981, test error 51.08
# Epoch   800, train loss 1.138278, train error 38.40,  test loss 1.511058, test error 52.05
# Epoch   900, train loss 1.128532, train error 38.92,  test loss 1.490481, test error 50.62
# Training model with  22 hidden variables
# Epoch     0, train loss 2.223417, train error 80.70,  test loss 2.207788, test error 80.28
# Epoch   100, train loss 1.281892, train error 42.22,  test loss 1.332904, test error 50.12
# Epoch   200, train loss 1.147037, train error 38.78,  test loss 1.391793, test error 51.10
# Epoch   300, train loss 1.086949, train error 36.55,  test loss 1.476109, test error 52.05
# Epoch   400, train loss 1.048670, train error 36.17,  test loss 1.562400, test error 51.65
# Epoch   500, train loss 1.013011, train error 34.30,  test loss 1.596934, test error 51.40
# Epoch   600, train loss 1.010557, train error 34.55,  test loss 1.654240, test error 51.90
# Epoch   700, train loss 0.988364, train error 33.07,  test loss 1.678660, test error 52.47
# Epoch   800, train loss 0.989927, train error 34.00,  test loss 1.729738, test error 52.38
# Epoch   900, train loss 0.963512, train error 32.43,  test loss 1.756045, test error 52.35
# Training model with  26 hidden variables
# Epoch     0, train loss 2.161041, train error 80.43,  test loss 2.139399, test error 79.47
# Epoch   100, train loss 1.211608, train error 39.83,  test loss 1.283539, test error 47.85
# Epoch   200, train loss 1.075934, train error 36.62,  test loss 1.409154, test error 49.38
# Epoch   300, train loss 0.973645, train error 33.03,  test loss 1.502187, test error 50.33
# Epoch   400, train loss 0.923363, train error 31.75,  test loss 1.639331, test error 51.53
# Epoch   500, train loss 0.893295, train error 30.72,  test loss 1.735422, test error 52.30
# Epoch   600, train loss 0.869457, train error 30.00,  test loss 1.797712, test error 51.12
# Epoch   700, train loss 0.842725, train error 28.62,  test loss 1.873756, test error 52.42
# Epoch   800, train loss 0.835831, train error 28.85,  test loss 1.938023, test error 51.53
# Epoch   900, train loss 0.852699, train error 30.05,  test loss 2.074203, test error 53.42
# Training model with  30 hidden variables
# Epoch     0, train loss 2.164292, train error 79.75,  test loss 2.142752, test error 79.10
# Epoch   100, train loss 1.120958, train error 36.58,  test loss 1.352897, test error 49.08
# Epoch   200, train loss 0.947864, train error 31.78,  test loss 1.550606, test error 51.42
# Epoch   300, train loss 0.850375, train error 28.53,  test loss 1.692789, test error 51.42
# Epoch   400, train loss 0.807596, train error 27.40,  test loss 1.849494, test error 53.05
# Epoch   500, train loss 0.758685, train error 25.35,  test loss 1.991332, test error 53.42
# Epoch   600, train loss 0.734536, train error 24.20,  test loss 2.163536, test error 54.65
# Epoch   700, train loss 0.720763, train error 24.28,  test loss 2.262278, test error 55.35
# Epoch   800, train loss 0.686655, train error 22.93,  test loss 2.363325, test error 54.97
# Epoch   900, train loss 0.673727, train error 22.85,  test loss 2.446268, test error 54.75
# Training model with  35 hidden variables
# Epoch     0, train loss 2.191975, train error 80.32,  test loss 2.180361, test error 81.53
# Epoch   100, train loss 1.015539, train error 31.47,  test loss 1.399620, test error 49.53
# Epoch   200, train loss 0.788879, train error 25.40,  test loss 1.680880, test error 51.88
# Epoch   300, train loss 0.676022, train error 22.10,  test loss 2.031744, test error 52.80
# Epoch   400, train loss 0.592186, train error 18.95,  test loss 2.369915, test error 53.85
# Epoch   500, train loss 0.555949, train error 18.18,  test loss 2.757118, test error 54.45
# Epoch   600, train loss 0.513047, train error 16.43,  test loss 3.077058, test error 56.05
# Epoch   700, train loss 0.479555, train error 15.45,  test loss 3.372258, test error 56.20
# Epoch   800, train loss 0.446073, train error 14.50,  test loss 3.751015, test error 56.75
# Epoch   900, train loss 0.465182, train error 15.50,  test loss 4.046853, test error 57.22
# Training model with  40 hidden variables
# Epoch     0, train loss 2.147202, train error 79.43,  test loss 2.105645, test error 77.88
# Epoch   100, train loss 0.914518, train error 30.70,  test loss 1.450078, test error 50.17
# Epoch   200, train loss 0.639953, train error 21.20,  test loss 1.884400, test error 52.03
# Epoch   300, train loss 0.472592, train error 15.93,  test loss 2.504012, test error 54.12
# Epoch   400, train loss 0.385317, train error 12.82,  test loss 3.324294, test error 55.12
# Epoch   500, train loss 0.308033, train error 9.65,  test loss 4.054962, test error 55.50
# Epoch   600, train loss 0.312062, train error 11.40,  test loss 4.940888, test error 56.72
# Epoch   700, train loss 0.236809, train error 8.03,  test loss 5.658092, test error 57.10
# Epoch   800, train loss 0.227509, train error 8.05,  test loss 6.284565, test error 56.72
# Epoch   900, train loss 0.286203, train error 10.57,  test loss 6.881909, test error 57.20
# Training model with  45 hidden variables
# Epoch     0, train loss 2.074933, train error 76.25,  test loss 2.036514, test error 76.90
# Epoch   100, train loss 0.788893, train error 24.75,  test loss 1.551507, test error 49.80
# Epoch   200, train loss 0.466412, train error 14.43,  test loss 2.396937, test error 53.35
# Epoch   300, train loss 0.287354, train error 8.50,  test loss 3.538154, test error 55.65
# Epoch   400, train loss 0.181527, train error 4.32,  test loss 4.848373, test error 57.00
# Epoch   500, train loss 0.133969, train error 4.03,  test loss 6.191459, test error 57.05
# Epoch   600, train loss 0.055262, train error 0.88,  test loss 7.429544, test error 57.17
# Epoch   700, train loss 0.013557, train error 0.00,  test loss 8.542415, test error 57.95
# Epoch   800, train loss 0.008865, train error 0.00,  test loss 9.261493, test error 57.70
# Epoch   900, train loss 0.006565, train error 0.00,  test loss 9.800986, test error 57.72
# Training model with  50 hidden variables
# Epoch     0, train loss 2.105561, train error 77.00,  test loss 2.066892, test error 76.75
# Epoch   100, train loss 0.701446, train error 22.28,  test loss 1.586089, test error 50.15
# Epoch   200, train loss 0.335203, train error 9.38,  test loss 2.617853, test error 52.75
# Epoch   300, train loss 0.166168, train error 4.30,  test loss 4.202711, test error 54.88
# Epoch   400, train loss 0.030519, train error 0.00,  test loss 5.796230, test error 54.67
# Epoch   500, train loss 0.013973, train error 0.00,  test loss 6.816707, test error 55.08
# Epoch   600, train loss 0.008586, train error 0.00,  test loss 7.482013, test error 55.42
# Epoch   700, train loss 0.006136, train error 0.00,  test loss 7.961682, test error 55.20
# Epoch   800, train loss 0.004687, train error 0.00,  test loss 8.354119, test error 55.33
# Epoch   900, train loss 0.003771, train error 0.00,  test loss 8.683791, test error 55.22
# Training model with  55 hidden variables
# Epoch     0, train loss 2.060076, train error 76.10,  test loss 2.014801, test error 75.72
# Epoch   100, train loss 0.610513, train error 18.07,  test loss 1.656952, test error 50.45
# Epoch   200, train loss 0.222628, train error 6.03,  test loss 2.982329, test error 52.15
# Epoch   300, train loss 0.030405, train error 0.00,  test loss 4.524457, test error 53.55
# Epoch   400, train loss 0.012394, train error 0.00,  test loss 5.415879, test error 54.30
# Epoch   500, train loss 0.007447, train error 0.00,  test loss 5.956632, test error 54.15
# Epoch   600, train loss 0.005136, train error 0.00,  test loss 6.354414, test error 54.38
# Epoch   700, train loss 0.003877, train error 0.00,  test loss 6.663924, test error 54.40
# Epoch   800, train loss 0.003099, train error 0.00,  test loss 6.915247, test error 54.25
# Epoch   900, train loss 0.002552, train error 0.00,  test loss 7.129278, test error 54.45
# Training model with  60 hidden variables
# Epoch     0, train loss 2.062261, train error 78.10,  test loss 2.004787, test error 76.53
# Epoch   100, train loss 0.540570, train error 16.50,  test loss 1.663835, test error 50.53
# Epoch   200, train loss 0.101047, train error 0.95,  test loss 3.173496, test error 53.80
# Epoch   300, train loss 0.019734, train error 0.00,  test loss 4.463260, test error 54.60
# Epoch   400, train loss 0.009505, train error 0.00,  test loss 5.120228, test error 54.65
# Epoch   500, train loss 0.005917, train error 0.00,  test loss 5.555820, test error 54.45
# Epoch   600, train loss 0.004243, train error 0.00,  test loss 5.875973, test error 54.30
# Epoch   700, train loss 0.003235, train error 0.00,  test loss 6.138368, test error 54.33
# Epoch   800, train loss 0.002615, train error 0.00,  test loss 6.352318, test error 54.62
# Epoch   900, train loss 0.002160, train error 0.00,  test loss 6.534471, test error 54.67
# Training model with  70 hidden variables
# Epoch     0, train loss 2.053830, train error 76.53,  test loss 2.014714, test error 76.80
# Epoch   100, train loss 0.347840, train error 8.15,  test loss 1.992968, test error 52.88
# Epoch   200, train loss 0.030984, train error 0.00,  test loss 3.619792, test error 54.35
# Epoch   300, train loss 0.010570, train error 0.00,  test loss 4.406574, test error 53.80
# Epoch   400, train loss 0.005960, train error 0.00,  test loss 4.847503, test error 53.60
# Epoch   500, train loss 0.003999, train error 0.00,  test loss 5.156986, test error 53.80
# Epoch   600, train loss 0.002948, train error 0.00,  test loss 5.390180, test error 53.80
# Epoch   700, train loss 0.002319, train error 0.00,  test loss 5.574487, test error 53.85
# Epoch   800, train loss 0.001893, train error 0.00,  test loss 5.730606, test error 53.78
# Epoch   900, train loss 0.001593, train error 0.00,  test loss 5.864012, test error 53.72
# Training model with  80 hidden variables
# Epoch     0, train loss 2.009120, train error 75.38,  test loss 1.939688, test error 76.10
# Epoch   100, train loss 0.244779, train error 4.75,  test loss 2.073213, test error 52.12
# Epoch   200, train loss 0.020488, train error 0.00,  test loss 3.451365, test error 52.67
# Epoch   300, train loss 0.008165, train error 0.00,  test loss 4.001763, test error 52.78
# Epoch   400, train loss 0.004805, train error 0.00,  test loss 4.334290, test error 52.85
# Epoch   500, train loss 0.003319, train error 0.00,  test loss 4.570301, test error 52.92
# Epoch   600, train loss 0.002488, train error 0.00,  test loss 4.755679, test error 52.80
# Epoch   700, train loss 0.001971, train error 0.00,  test loss 4.905619, test error 52.85
# Epoch   800, train loss 0.001624, train error 0.00,  test loss 5.032632, test error 52.95
# Epoch   900, train loss 0.001373, train error 0.00,  test loss 5.142311, test error 53.05
# Training model with  90 hidden variables
# Epoch     0, train loss 2.022701, train error 74.45,  test loss 1.976351, test error 74.75
# Epoch   100, train loss 0.131903, train error 0.82,  test loss 2.164244, test error 50.53
# Epoch   200, train loss 0.014652, train error 0.00,  test loss 3.217721, test error 50.33
# Epoch   300, train loss 0.006529, train error 0.00,  test loss 3.644326, test error 50.25
# Epoch   400, train loss 0.004004, train error 0.00,  test loss 3.912745, test error 50.40
# Epoch   500, train loss 0.002817, train error 0.00,  test loss 4.105975, test error 50.50
# Epoch   600, train loss 0.002141, train error 0.00,  test loss 4.255950, test error 50.53
# Epoch   700, train loss 0.001713, train error 0.00,  test loss 4.379973, test error 50.38
# Epoch   800, train loss 0.001418, train error 0.00,  test loss 4.485792, test error 50.50
# Epoch   900, train loss 0.001204, train error 0.00,  test loss 4.577041, test error 50.65
# Training model with 100 hidden variables
# Epoch     0, train loss 2.016165, train error 74.28,  test loss 1.953036, test error 73.03
# Epoch   100, train loss 0.097243, train error 0.22,  test loss 2.234485, test error 50.83
# Epoch   200, train loss 0.012304, train error 0.00,  test loss 3.100540, test error 51.20
# Epoch   300, train loss 0.005743, train error 0.00,  test loss 3.468142, test error 51.22
# Epoch   400, train loss 0.003569, train error 0.00,  test loss 3.699670, test error 51.28
# Epoch   500, train loss 0.002534, train error 0.00,  test loss 3.869538, test error 51.38
# Epoch   600, train loss 0.001937, train error 0.00,  test loss 4.002541, test error 51.53
# Epoch   700, train loss 0.001555, train error 0.00,  test loss 4.111703, test error 51.55
# Epoch   800, train loss 0.001291, train error 0.00,  test loss 4.204928, test error 51.62
# Epoch   900, train loss 0.001099, train error 0.00,  test loss 4.284981, test error 51.62
# Training model with 120 hidden variables
# Epoch     0, train loss 1.955296, train error 72.65,  test loss 1.896316, test error 73.30
# Epoch   100, train loss 0.054651, train error 0.00,  test loss 2.194800, test error 51.33
# Epoch   200, train loss 0.009814, train error 0.00,  test loss 2.827738, test error 51.67
# Epoch   300, train loss 0.004826, train error 0.00,  test loss 3.112016, test error 51.53
# Epoch   400, train loss 0.003067, train error 0.00,  test loss 3.290831, test error 51.47
# Epoch   500, train loss 0.002211, train error 0.00,  test loss 3.425186, test error 51.55
# Epoch   600, train loss 0.001708, train error 0.00,  test loss 3.531016, test error 51.67
# Epoch   700, train loss 0.001380, train error 0.00,  test loss 3.619392, test error 51.62
# Epoch   800, train loss 0.001152, train error 0.00,  test loss 3.693504, test error 51.67
# Epoch   900, train loss 0.000984, train error 0.00,  test loss 3.759851, test error 51.58
# Training model with 140 hidden variables
# Epoch     0, train loss 1.956122, train error 71.95,  test loss 1.878738, test error 72.12
# Epoch   100, train loss 0.038721, train error 0.00,  test loss 2.193647, test error 49.97
# Epoch   200, train loss 0.008345, train error 0.00,  test loss 2.715268, test error 50.90
# Epoch   300, train loss 0.004244, train error 0.00,  test loss 2.948885, test error 50.38
# Epoch   400, train loss 0.002736, train error 0.00,  test loss 3.103890, test error 50.55
# Epoch   500, train loss 0.001986, train error 0.00,  test loss 3.219802, test error 50.62
# Epoch   600, train loss 0.001543, train error 0.00,  test loss 3.311331, test error 50.55
# Epoch   700, train loss 0.001252, train error 0.00,  test loss 3.389135, test error 50.55
# Epoch   800, train loss 0.001048, train error 0.00,  test loss 3.455351, test error 50.62
# Epoch   900, train loss 0.000897, train error 0.00,  test loss 3.512404, test error 50.53
# Training model with 160 hidden variables
# Epoch     0, train loss 1.925999, train error 70.05,  test loss 1.862449, test error 71.53
# Epoch   100, train loss 0.028896, train error 0.00,  test loss 2.127489, test error 49.38
# Epoch   200, train loss 0.007142, train error 0.00,  test loss 2.533361, test error 49.62
# Epoch   300, train loss 0.003756, train error 0.00,  test loss 2.733668, test error 49.50
# Epoch   400, train loss 0.002475, train error 0.00,  test loss 2.868491, test error 49.47
# Epoch   500, train loss 0.001813, train error 0.00,  test loss 2.969596, test error 49.38
# Epoch   600, train loss 0.001414, train error 0.00,  test loss 3.047890, test error 49.22
# Epoch   700, train loss 0.001152, train error 0.00,  test loss 3.115028, test error 49.20
# Epoch   800, train loss 0.000967, train error 0.00,  test loss 3.172813, test error 49.20
# Epoch   900, train loss 0.000830, train error 0.00,  test loss 3.222006, test error 49.25
# Training model with 180 hidden variables
# Epoch     0, train loss 1.914291, train error 69.15,  test loss 1.838441, test error 71.57
# Epoch   100, train loss 0.023551, train error 0.00,  test loss 2.012825, test error 48.15
# Epoch   200, train loss 0.006444, train error 0.00,  test loss 2.347050, test error 48.28
# Epoch   300, train loss 0.003461, train error 0.00,  test loss 2.515451, test error 48.15
# Epoch   400, train loss 0.002297, train error 0.00,  test loss 2.628309, test error 48.22
# Epoch   500, train loss 0.001693, train error 0.00,  test loss 2.713357, test error 48.12
# Epoch   600, train loss 0.001326, train error 0.00,  test loss 2.781755, test error 48.17
# Epoch   700, train loss 0.001084, train error 0.00,  test loss 2.838958, test error 48.35
# Epoch   800, train loss 0.000911, train error 0.00,  test loss 2.887783, test error 48.33
# Epoch   900, train loss 0.000784, train error 0.00,  test loss 2.930531, test error 48.35
# Training model with 200 hidden variables
# Epoch     0, train loss 1.914485, train error 69.90,  test loss 1.837104, test error 71.47
# Epoch   100, train loss 0.021509, train error 0.00,  test loss 1.984863, test error 46.97
# Epoch   200, train loss 0.006114, train error 0.00,  test loss 2.292333, test error 46.72
# Epoch   300, train loss 0.003324, train error 0.00,  test loss 2.449071, test error 46.88
# Epoch   400, train loss 0.002216, train error 0.00,  test loss 2.556040, test error 46.88
# Epoch   500, train loss 0.001637, train error 0.00,  test loss 2.635774, test error 46.90
# Epoch   600, train loss 0.001286, train error 0.00,  test loss 2.699700, test error 46.97
# Epoch   700, train loss 0.001052, train error 0.00,  test loss 2.753646, test error 46.95
# Epoch   800, train loss 0.000886, train error 0.00,  test loss 2.799359, test error 46.97
# Epoch   900, train loss 0.000763, train error 0.00,  test loss 2.839457, test error 46.95
# Training model with 250 hidden variables
# Epoch     0, train loss 1.882901, train error 68.05,  test loss 1.816579, test error 70.10
# Epoch   100, train loss 0.016941, train error 0.00,  test loss 1.928173, test error 47.78
# Epoch   200, train loss 0.005305, train error 0.00,  test loss 2.184602, test error 47.65
# Epoch   300, train loss 0.002952, train error 0.00,  test loss 2.321597, test error 47.67
# Epoch   400, train loss 0.001992, train error 0.00,  test loss 2.415308, test error 47.53
# Epoch   500, train loss 0.001482, train error 0.00,  test loss 2.487136, test error 47.58
# Epoch   600, train loss 0.001170, train error 0.00,  test loss 2.544274, test error 47.60
# Epoch   700, train loss 0.000960, train error 0.00,  test loss 2.592360, test error 47.60
# Epoch   800, train loss 0.000811, train error 0.00,  test loss 2.633891, test error 47.65
# Epoch   900, train loss 0.000699, train error 0.00,  test loss 2.670820, test error 47.70
# Training model with 300 hidden variables
# Epoch     0, train loss 1.888459, train error 68.75,  test loss 1.825851, test error 70.68
# Epoch   100, train loss 0.014330, train error 0.00,  test loss 1.916194, test error 47.62
# Epoch   200, train loss 0.004786, train error 0.00,  test loss 2.140195, test error 47.40
# Epoch   300, train loss 0.002721, train error 0.00,  test loss 2.264217, test error 47.35
# Epoch   400, train loss 0.001853, train error 0.00,  test loss 2.348908, test error 47.17
# Epoch   500, train loss 0.001387, train error 0.00,  test loss 2.413812, test error 47.20
# Epoch   600, train loss 0.001099, train error 0.00,  test loss 2.466113, test error 47.15
# Epoch   700, train loss 0.000905, train error 0.00,  test loss 2.510371, test error 47.12
# Epoch   800, train loss 0.000766, train error 0.00,  test loss 2.548242, test error 47.10
# Epoch   900, train loss 0.000662, train error 0.00,  test loss 2.581799, test error 47.17
# Training model with 400 hidden variables
# Epoch     0, train loss 1.861793, train error 67.05,  test loss 1.812344, test error 70.10
# Epoch   100, train loss 0.011986, train error 0.00,  test loss 1.773881, test error 45.75
# Epoch   200, train loss 0.004252, train error 0.00,  test loss 1.950775, test error 45.78
# Epoch   300, train loss 0.002454, train error 0.00,  test loss 2.048326, test error 45.75
# Epoch   400, train loss 0.001689, train error 0.00,  test loss 2.116888, test error 45.60
# Epoch   500, train loss 0.001272, train error 0.00,  test loss 2.169051, test error 45.65
# Epoch   600, train loss 0.001013, train error 0.00,  test loss 2.211831, test error 45.62
# Epoch   700, train loss 0.000837, train error 0.00,  test loss 2.247457, test error 45.62
# Epoch   800, train loss 0.000710, train error 0.00,  test loss 2.278503, test error 45.65
# Epoch   900, train loss 0.000615, train error 0.00,  test loss 2.305608, test error 45.62

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
