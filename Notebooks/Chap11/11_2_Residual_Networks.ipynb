# %% [markdown]
# <a href="https://colab.research.google.com/github/Mutriz/AI-Assignments/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-4novcw6d
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-4novcw6d
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
import torch, torch.nn as nn

# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()

    # First residual block
    h2_input = h1 # The input to the residual block is h1
    h2 = self.linear2(h2_input).relu() # Apply linear2 and ReLU
    h2 = h2_input + h2 # Add the residual connection

    # Second residual block
    h3_input = h2 # The input to the residual block is h2
    h3 = self.linear3(h3_input).relu() # Apply linear3 and ReLU
    h3 = h3_input + h3 # Add the residual connection

    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.588539, train error 63.40,  val loss 1.675849, percent error 67.90
# Epoch     1, train loss 1.307542, train error 48.88,  val loss 1.446185, percent error 58.50
# Epoch     2, train loss 1.153266, train error 44.05,  val loss 1.338560, percent error 51.20
# Epoch     3, train loss 0.994053, train error 36.53,  val loss 1.249524, percent error 49.20
# Epoch     4, train loss 0.852517, train error 31.22,  val loss 1.182232, percent error 46.90
# Epoch     5, train loss 0.728244, train error 26.53,  val loss 1.116315, percent error 42.40
# Epoch     6, train loss 0.669170, train error 24.20,  val loss 1.140382, percent error 41.90
# Epoch     7, train loss 0.587945, train error 21.38,  val loss 1.175818, percent error 43.20
# Epoch     8, train loss 0.465362, train error 16.45,  val loss 1.134384, percent error 38.80
# Epoch     9, train loss 0.406622, train error 14.93,  val loss 1.138211, percent error 38.20
# Epoch    10, train loss 0.353959, train error 12.28,  val loss 1.177586, percent error 37.20
# Epoch    11, train loss 0.322857, train error 11.00,  val loss 1.297655, percent error 40.00
# Epoch    12, train loss 0.266299, train error 8.82,  val loss 1.255794, percent error 38.20
# Epoch    13, train loss 0.210972, train error 6.82,  val loss 1.317327, percent error 37.10
# Epoch    14, train loss 0.210685, train error 7.40,  val loss 1.341114, percent error 36.70
# Epoch    15, train loss 0.184554, train error 6.45,  val loss 1.383416, percent error 36.30
# Epoch    16, train loss 0.184843, train error 6.45,  val loss 1.521417, percent error 36.60
# Epoch    17, train loss 0.187915, train error 6.25,  val loss 1.658965, percent error 38.10
# Epoch    18, train loss 0.239602, train error 8.43,  val loss 1.681474, percent error 40.60
# Epoch    19, train loss 0.183422, train error 6.12,  val loss 1.615921, percent error 40.10
# Epoch    20, train loss 0.052723, train error 1.07,  val loss 1.516123, percent error 36.30
# Epoch    21, train loss 0.022561, train error 0.05,  val loss 1.490577, percent error 34.40
# Epoch    22, train loss 0.014560, train error 0.00,  val loss 1.547405, percent error 35.20
# Epoch    23, train loss 0.011023, train error 0.00,  val loss 1.566993, percent error 34.70
# Epoch    24, train loss 0.009222, train error 0.00,  val loss 1.591113, percent error 34.60
# Epoch    25, train loss 0.008200, train error 0.00,  val loss 1.619582, percent error 34.70
# Epoch    26, train loss 0.007274, train error 0.00,  val loss 1.646610, percent error 34.50
# Epoch    27, train loss 0.006433, train error 0.00,  val loss 1.667023, percent error 34.20
# Epoch    28, train loss 0.005821, train error 0.00,  val loss 1.682862, percent error 34.50
# Epoch    29, train loss 0.005365, train error 0.00,  val loss 1.695396, percent error 34.80
# Epoch    30, train loss 0.004957, train error 0.00,  val loss 1.714809, percent error 34.30
# Epoch    31, train loss 0.004650, train error 0.00,  val loss 1.728198, percent error 34.20
# Epoch    32, train loss 0.004352, train error 0.00,  val loss 1.742454, percent error 34.50
# Epoch    33, train loss 0.004090, train error 0.00,  val loss 1.753029, percent error 34.70
# Epoch    34, train loss 0.003859, train error 0.00,  val loss 1.768107, percent error 33.80
# Epoch    35, train loss 0.003656, train error 0.00,  val loss 1.776766, percent error 34.30
# Epoch    36, train loss 0.003465, train error 0.00,  val loss 1.789273, percent error 34.20
# Epoch    37, train loss 0.003278, train error 0.00,  val loss 1.797511, percent error 34.20
# Epoch    38, train loss 0.003150, train error 0.00,  val loss 1.807136, percent error 34.10
# Epoch    39, train loss 0.002997, train error 0.00,  val loss 1.816617, percent error 33.90
# Epoch    40, train loss 0.002928, train error 0.00,  val loss 1.820967, percent error 34.20
# Epoch    41, train loss 0.002867, train error 0.00,  val loss 1.826563, percent error 34.10
# Epoch    42, train loss 0.002809, train error 0.00,  val loss 1.830585, percent error 33.90
# Epoch    43, train loss 0.002755, train error 0.00,  val loss 1.835308, percent error 33.90
# Epoch    44, train loss 0.002701, train error 0.00,  val loss 1.839790, percent error 34.10
# Epoch    45, train loss 0.002650, train error 0.00,  val loss 1.843780, percent error 34.10
# Epoch    46, train loss 0.002600, train error 0.00,  val loss 1.847457, percent error 34.00
# Epoch    47, train loss 0.002552, train error 0.00,  val loss 1.851979, percent error 34.00
# Epoch    48, train loss 0.002506, train error 0.00,  val loss 1.854919, percent error 34.10
# Epoch    49, train loss 0.002463, train error 0.00,  val loss 1.858958, percent error 33.70
# Epoch    50, train loss 0.002420, train error 0.00,  val loss 1.864238, percent error 34.00
# Epoch    51, train loss 0.002378, train error 0.00,  val loss 1.867386, percent error 34.10
# Epoch    52, train loss 0.002338, train error 0.00,  val loss 1.871806, percent error 33.90
# Epoch    53, train loss 0.002299, train error 0.00,  val loss 1.875287, percent error 33.90
# Epoch    54, train loss 0.002261, train error 0.00,  val loss 1.879158, percent error 34.10
# Epoch    55, train loss 0.002225, train error 0.00,  val loss 1.882630, percent error 33.90
# Epoch    56, train loss 0.002189, train error 0.00,  val loss 1.886005, percent error 33.80
# Epoch    57, train loss 0.002154, train error 0.00,  val loss 1.890003, percent error 33.80
# Epoch    58, train loss 0.002121, train error 0.00,  val loss 1.893157, percent error 33.70
# Epoch    59, train loss 0.002089, train error 0.00,  val loss 1.896877, percent error 33.80
# Epoch    60, train loss 0.002073, train error 0.00,  val loss 1.898581, percent error 33.60
# Epoch    61, train loss 0.002058, train error 0.00,  val loss 1.900584, percent error 33.70
# Epoch    62, train loss 0.002042, train error 0.00,  val loss 1.901608, percent error 33.80
# Epoch    63, train loss 0.002027, train error 0.00,  val loss 1.903609, percent error 33.70
# Epoch    64, train loss 0.002012, train error 0.00,  val loss 1.905475, percent error 33.80
# Epoch    65, train loss 0.001997, train error 0.00,  val loss 1.906884, percent error 33.80
# Epoch    66, train loss 0.001983, train error 0.00,  val loss 1.908481, percent error 33.60
# Epoch    67, train loss 0.001969, train error 0.00,  val loss 1.910200, percent error 33.70
# Epoch    68, train loss 0.001955, train error 0.00,  val loss 1.912261, percent error 33.60
# Epoch    69, train loss 0.001941, train error 0.00,  val loss 1.913361, percent error 33.80
# Epoch    70, train loss 0.001928, train error 0.00,  val loss 1.915091, percent error 33.70
# Epoch    71, train loss 0.001914, train error 0.00,  val loss 1.916743, percent error 33.50
# Epoch    72, train loss 0.001901, train error 0.00,  val loss 1.918278, percent error 33.40
# Epoch    73, train loss 0.001888, train error 0.00,  val loss 1.919915, percent error 33.50
# Epoch    74, train loss 0.001875, train error 0.00,  val loss 1.921434, percent error 33.60
# Epoch    75, train loss 0.001863, train error 0.00,  val loss 1.923189, percent error 33.60
# Epoch    76, train loss 0.001850, train error 0.00,  val loss 1.924628, percent error 33.50
# Epoch    77, train loss 0.001838, train error 0.00,  val loss 1.925948, percent error 33.50
# Epoch    78, train loss 0.001825, train error 0.00,  val loss 1.927328, percent error 33.50
# Epoch    79, train loss 0.001814, train error 0.00,  val loss 1.929560, percent error 33.50
# Epoch    80, train loss 0.001807, train error 0.00,  val loss 1.929913, percent error 33.50
# Epoch    81, train loss 0.001802, train error 0.00,  val loss 1.930937, percent error 33.50
# Epoch    82, train loss 0.001796, train error 0.00,  val loss 1.931346, percent error 33.50
# Epoch    83, train loss 0.001790, train error 0.00,  val loss 1.932205, percent error 33.50
# Epoch    84, train loss 0.001784, train error 0.00,  val loss 1.932878, percent error 33.50
# Epoch    85, train loss 0.001778, train error 0.00,  val loss 1.933553, percent error 33.50
# Epoch    86, train loss 0.001773, train error 0.00,  val loss 1.934534, percent error 33.50
# Epoch    87, train loss 0.001767, train error 0.00,  val loss 1.935225, percent error 33.50
# Epoch    88, train loss 0.001761, train error 0.00,  val loss 1.935929, percent error 33.50
# Epoch    89, train loss 0.001756, train error 0.00,  val loss 1.936578, percent error 33.50
# Epoch    90, train loss 0.001750, train error 0.00,  val loss 1.937382, percent error 33.50
# Epoch    91, train loss 0.001745, train error 0.00,  val loss 1.937922, percent error 33.50
# Epoch    92, train loss 0.001739, train error 0.00,  val loss 1.938889, percent error 33.50
# Epoch    93, train loss 0.001734, train error 0.00,  val loss 1.939409, percent error 33.50
# Epoch    94, train loss 0.001728, train error 0.00,  val loss 1.940354, percent error 33.60
# Epoch    95, train loss 0.001723, train error 0.00,  val loss 1.940874, percent error 33.70
# Epoch    96, train loss 0.001717, train error 0.00,  val loss 1.941969, percent error 33.60
# Epoch    97, train loss 0.001712, train error 0.00,  val loss 1.942606, percent error 33.70
# Epoch    98, train loss 0.001707, train error 0.00,  val loss 1.943281, percent error 33.70
# Epoch    99, train loss 0.001702, train error 0.00,  val loss 1.943899, percent error 33.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
